# %% [markdown]
# What is the relationship between p-value and t-test?
#
# The larger the absolute value of the t-value, the smaller the p-value, and the greater the evidence against the null hypothesis

# %% [markdown]
# T is simply the calculated difference represented in units of standard error. The greater the magnitude of T, the greater the evidence against the null hypothesis. This means there is greater evidence that there is a significant difference. The closer T is to 0, the more likely there isn't a significant difference.

# %% [markdown]
# The p-value is a measure of the evidence against the null hypothesis. A smaller p-value suggests stronger evidence against the null hypothesis, while a larger p-value suggests weaker evidence.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

# Define degrees of freedom
df = 10  # You can change this value

# Generate x values
x = np.linspace(-4, 4, 1000)

# Calculate the probability density function (PDF) for the t-distribution
pdf = t.pdf(x, df)

# Plot the t-distribution
plt.plot(x, pdf, label=f't-distribution (df={df})')

# Add a vertical line at a specific x-value (representing a critical value or test statistic)
critical_value = 1.96  # You can change this value

# CDF calculates the cumulative distribution function (CDF) of the t-distribution at the point critical_value with df degrees of freedom.
# The result represents the probability of observing a value less than or equal to critical_value under the t-distribution.
plt.axvline(critical_value, color='red', linestyle='--', label=f'Critical Value\n(x={critical_value})')

# Annotate the p-value
plt.text(critical_value, 0.25, f'p-value = {1 - t.cdf(critical_value, df):.4f}', color='red')

# Customize the plot
plt.title('T-Distribution with Critical Value')
plt.xlabel('x')
plt.ylabel('Probability Density Function (PDF)')
plt.legend()
plt.grid(True)
plt.show()
